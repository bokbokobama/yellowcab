# %% [markdown]
# <a href="https://colab.research.google.com/github/bokbokobama/yellowcab/blob/main/yellowcab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.DataFrame()
df.iloc[0:0]
 

# Create a list of every month from January 2009 to June 2022, in a format which mat
urlList = pd.date_range('2009-01-01','2022-06-01', freq='MS').strftime("%Y-%m").tolist()

for month in urlList[-6:]: # Change the index in urlList to view a different range of months. Default is [-6:], including 2022-01 - 2022-06.
  print('> ' + month)
  df = df.append(pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_' + month + '.parquet'), ignore_index = True)
print('> Successfully created dataframe')

db
# Out:
# > 2022-01
# > 2022-02
# > 2022-03
# > 2022-04
# > 2022-05
# > 2022-06
# > Successfully created dataframe

# %%
df #.dropna(subset = ["VendorID"])
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0                1  2022-01-01 00:35:40   2022-01-01 00:53:29
# 1                1  2022-01-01 00:33:43   2022-01-01 00:42:07
# 2                2  2022-01-01 00:53:21   2022-01-01 01:02:19
# 3                2  2022-01-01 00:25:21   2022-01-01 00:35:23
# 4                2  2022-01-01 00:36:48   2022-01-01 01:14:20
# ...            ...                  ...                   ...
# 19817578         1  2022-06-30 23:45:51   2022-06-30 23:51:48
# 19817579         2  2022-06-30 23:25:00   2022-06-30 23:40:00
# 19817580         2  2022-06-30 23:29:00   2022-06-30 23:37:00
# 19817581         2  2022-06-30 23:24:15   2022-06-30 23:50:19
# 19817582         2  2022-06-30 23:33:53   2022-06-30 23:54:58
#
#           passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                     2.0           3.80         1.0                  N
# 1                     1.0           2.10         1.0                  N
# ...
